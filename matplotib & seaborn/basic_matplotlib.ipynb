# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
#HISTPLOT
x =np.random.normal(170,10,250)

# %%
x
# Out:
# array([171.41534678, 168.9774446 , 177.19547484, 169.70968763,
#        167.61791157, 157.7782806 , 172.71797836, 183.44958385,
#        176.60875322, 179.2894386 , 172.86671663, 178.29157884,
#        199.12843365, 189.18385504, 159.87760192, 175.22847263,
#        170.42040918, 169.20517361, 175.31624687, 166.97123716,
#        168.91399644, 181.17028701, 151.62522278, 180.51379492,
#        167.95335691, 174.37657742, 175.74303795, 172.13566412,
#        175.08044851, 166.06354001, 151.13208659, 176.06387432,
#        163.61399826, 180.56156164, 170.66934955, 160.06117381,
#        178.39078562, 158.82694355, 184.48251396, 177.07094847,
#        176.93759675, 188.25316631, 178.5463237 , 173.88412132,
#        177.57462442, 158.40234095, 166.75811751, 171.87080046,
#        173.2283158 , 141.91805818, 160.95401624, 175.79880372,
#        172.78333298, 182.54366453, 174.08993511, 159.69071507,
#        169.95479019, 151.89568027, 155.96489153, 165.05112548,
# ...

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# Pie

# %%
x= np.array([1,2,3,4])
plt.pie(x)
plt.show()

# %%
x= np.array([1,2,3,4])
mylabels= np.array(["apple","banana","orange","mango"])
plt.pie(x, labels= mylabels, startangle=90)
plt.show()

# %%
x= np.array([1,2,3,4])
mylabels= np.array(["apple","banana","orange","mango"])
mexplo= np.array([0,3,0,0,0])
plt.pie(x, labels= mylabels, startangle=90,explode= mexplo)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       2 mylabels= np.array(["apple","banana","orange","mango"])
#       3 mexplo= np.array([0,3,0,0,0])
# ----> 4 plt.pie('x', labels= mylabels, startangle=90,explode= mexplo)
#       5 plt.show()
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
x= np.array([1,2,3,4])
mylabels= np.array(["apple","banana","orange","mango"])
myexplode= np.array([0,3,0,0,0])
colour =np.array(["red","green","blue","yellow"])
plt.pie(x, labels= mylabels, startangle=90,explode=myexplode, shadow=True, colours=colour)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       3 myexplode= np.array([0,3,0,0,0])
#       4 colour =np.array(["red","green","blue","yellow"])
# ----> 5 plt.pie(x, labels= mylabels, startangle=90,explode=myexplode, shadow=True, colours=colour)
#       6 plt.show()
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
x= np.array([1,2,3,4])
mylabels= np.array(["apple","banana","orange","mango"])
myexplode= np.array([0,3,0,0,0])
colour =np.array(["red","green","blue","yellow"])
plt.pie(x, labels= mylabels, startangle=90,explode=myexplode, shadow=True, colours= colour, autopct='%1.1%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       3 myexplode= np.array([0,3,0,0,0])
#       4 colour =np.array(["red","green","blue","yellow"])
# ----> 5 plt.pie(x, labels= mylabels, startangle=90,explode=myexplode, shadow=True, colours=colour, autopct='%1.1%')
#       6 plt.show()
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
