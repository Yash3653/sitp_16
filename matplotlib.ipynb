# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
x_point=np.array([1,3,4,5])
y_point=np.array([2,5,8,7])
plt.plot(x_point, y_point)
plt.show()

# %%
x_point=np.array([1,3,4,5])
y_point=np.array([2,5,8,7])
plt.plot(x_point, y_point,'o')
plt.show()

# %%
x_point=np.array([1,3,4,5])
y_point=np.array([2,5,8,7])
plt.plot(x_point, y_point,'*')
plt.show()

# %%
x_point=np.array([1,3,4,5])
#y_point=np.array([2,5,8,7])
plt.plot(x_point, 'o:b')
plt.show()

# %%
x_point=np.array([1,3,4,5])
#y_point=np.array([2,5,8,7])
plt.plot(x_point, marker = 'o', ms= 30) # ms=markersize
plt.show()

# %%
x_point=np.array([1,3,4,5])
#y_point=np.array([2,5,8,7])
plt.plot(x_point, marker = '*', ms = 30)
plt.show()

# %%
x_point=np.array([1,3,4,5])
#y_point=np.array([2,5,8,7])
plt.plot(x_point, marker = '*', ms = 30, mec='r',)# mec means boundry of marker(here stars)
plt.show()

# %%
x_point=np.array([1,3,4,5])
#y_point=np.array([2,5,8,7])
plt.plot(x_point, marker = '*', ms = 30, mec='r', mfc = 'g')# mfc inside marker g(green)
plt.show()

# %%
x_point=np.array([1,3,4,5])
#y_point=np.array([2,5,8,7])
plt.plot(x_point, ls = 'dotted')
plt.show()

# %%
x_point=np.array([1,3,4,5])
#y_point=np.array([2,5,8,7])
plt.plot(x_point, ls = 'dashed')
plt.show()

# %%
x_point=np.array([1,3,4,5])
#y_point=np.array([2,5,8,7])
plt.plot(x_point, linewidth = 5)
plt.show()

# %%
x_point=np.array([1,3,4,5])
y_point=np.array([2,5,8,7])
plt.plot(x_point)
plt.plot(y_point)## 'o' is used to create scatter plot
plt.show()

# %%
x_point=np.array([1,3,4,5])
y_point=np.array([2,5,8,7])
plt.xlabel("x point")
plt.ylabel("y point")
plt.title("data science")
plt.plot(x_point)
plt.plot(y_point)## 'o' is used to create scatter plot
plt.show()

# %%
x_point=np.array([1,3,4,5])
y_point=np.array([2,5,8,7])
plt.xlabel("x point")
plt.ylabel("y point")
plt.title("data science")
plt.grid()
plt.plot(x_point)
plt.plot(y_point)## 'o' is used to create scatter plot
plt.show()

# %%
x =np.array([1,2,3,4,5])
y=np.array([1,5,5,8,2])
#plt.xlabel("x axis")
#plt.ylabel("y axis")
#plt.grid()
plt.subplot(1,2,1)
plt.plot(x,y)
x =np.array([1,2,3,4,5])
y=np.array([1,5,5,8,2])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
### scatter graph

# %%
x = np.array([1,2,3,4,5])
y = np.array([2,4,9,16,28])
plt.scatter(x,y)






#colour = np.array(["red","yellow",""])

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
#c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y,s= sizes, c= c )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y,alpha =0.5, s = sizes, c = c )#alpha colour thickness 
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y,alpha=0.5, s = sizes, c = c, cmap="coolwarm" )
plt.colorbar()
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14872\4180336059.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y,alpha=0.5, s = sizes, c = c, cmap="coolwarm" )
