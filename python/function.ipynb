# %%
def add_two_numbers(a,b):
    print(a+b)

# %%
def temp(a , b):
    return a*b

# %%
def temp():
    print ("hello mate ")
    temp()

# %%
temp()
# Out:
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# hello mate
# ...

# %%
temp(a=10,b=20)
# Out:
# 200

# %%
temp(a=10,b=8)
# Out:
# 80
